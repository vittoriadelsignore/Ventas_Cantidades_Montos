# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
mpl.style.use("bmh")

# %%
data=pd.read_excel("Venta.xlsx")
data.head()
# Out:
#   COD TIENDA TIENDA               CLIENTE  Main Group Articulo  \
# 0         -1    NaN  Consumidores Finales                 -1.0
# 1         -1    NaN  Consumidores Finales                  2.0
# 2         -1    NaN  Consumidores Finales                  3.0
# 3         -1    NaN  Consumidores Finales                  4.0
# 4         -1    NaN  Consumidores Finales                  5.0
#
#                  PRODUCTO  Venta FEB21  Venta ENE21  Venta DIC20  Venta NOV20  \
# 0                   dummy          NaN          NaN          NaN          NaN
# 1    CERVEZAS Y REFRESCOS          NaN          NaN          NaN          NaN
# 2      ART. USO DOMESTICO          NaN          NaN          NaN          NaN
# 3                LIMPIEZA          NaN          NaN          NaN          NaN
# 4  PERFUMERIA Y DROGUERIA          NaN          NaN          NaN          NaN
#
#    Venta OCT20  ...  Ctd Vendida OCT19  Ctd Vendida SEP19  Ctd Vendida AGO19  \
# ...

# %%
data1=data.dropna(0)
data1.head()
# Out:
#    COD TIENDA TIENDA                CLIENTE  Main Group Articulo  \
# 52          1  Chaco  Comercio de Alimentos                  2.0
# 54          1  Chaco  Comercio de Alimentos                  4.0
# 55          1  Chaco  Comercio de Alimentos                  5.0
# 56          1  Chaco  Comercio de Alimentos                  6.0
# 57          1  Chaco  Comercio de Alimentos                  7.0
#
#                   PRODUCTO  Venta FEB21  Venta ENE21  Venta DIC20  \
# 52    CERVEZAS Y REFRESCOS   2442244.26   1720477.72   1478025.56
# 54                LIMPIEZA   1041420.45   1103360.17   1125417.01
# 55  PERFUMERIA Y DROGUERIA    329354.05    384351.71    393355.01
# 56         ALMACEN BASICOS    651796.92    746787.68   1007190.21
# 57     KIOSCO Y CONFITERIA    625157.21    700057.91    619160.25
#
#     Venta NOV20  Venta OCT20  ...  Ctd Vendida OCT19  Ctd Vendida SEP19  \
# 52   1097453.36   1313381.03  ...            24876.0            29805.0
# ...

# %%
data1.shape
# Out:
# (2087, 57)

# %%
data1.columns
# Out:
# Index(['COD TIENDA', 'TIENDA', 'CLIENTE', 'Main Group Articulo', 'PRODUCTO',
#        'Venta FEB21', 'Venta ENE21', 'Venta DIC20', 'Venta NOV20',
#        'Venta OCT20', 'Venta SEP20', 'Venta AGO20', 'Venta JUL20',
#        'Venta JUN20', 'Venta MAY20', 'Venta ABR20', 'Venta MAR20',
#        'Venta FEB20', 'Venta ENE20', 'Venta DIC19', 'Venta NOV19',
#        'Venta OCT19', 'Venta SEP19', 'Venta AGO19', 'Venta JUL19',
#        'Venta JUN19', 'Venta MAY19', 'Venta ABR19', 'Venta MAR19',
#        'Venta FEB19', 'Venta ENE19', 'Ctd Vendida FEB21', 'Ctd Vendida ENE21',
#        'Ctd Vendida DIC20', 'Ctd Vendida NOV20', 'Ctd Vendida OCT20',
#        'Ctd Vendida SEP20', 'Ctd Vendida AGO20', 'Ctd Vendida JUL20',
#        'Ctd Vendida JUN20', 'Ctd Vendida MAY20', 'Ctd Vendida ABR20',
#        'Ctd Vendida MAR20', 'Ctd Vendida FEB20', 'Ctd Vendida ENE20',
#        'Ctd Vendida DIC19', 'Ctd Vendida NOV19', 'Ctd Vendida OCT19',
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2087 entries, 52 to 6782
# Data columns (total 57 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   COD TIENDA           2087 non-null   object
#  1   TIENDA               2087 non-null   object
#  2   CLIENTE              2087 non-null   object
#  3   Main Group Articulo  2087 non-null   float64
#  4   PRODUCTO             2087 non-null   object
#  5   Venta FEB21          2087 non-null   float64
#  6   Venta ENE21          2087 non-null   float64
#  7   Venta DIC20          2087 non-null   float64
#  8   Venta NOV20          2087 non-null   float64
#  9   Venta OCT20          2087 non-null   float64
#  10  Venta SEP20          2087 non-null   float64
#  11  Venta AGO20          2087 non-null   float64
#  12  Venta JUL20          2087 non-null   float64
#  13  Venta JUN20          2087 non-null   float64
#  14  Venta MAY20          2087 non-null   float64
# ...

# %%
sns.set(rc = {'figure.figsize':(15,6)})
sns.set_style('white')

# %%
sns.countplot(x='CLIENTE', data= data1)
# Out:
# <AxesSubplot:xlabel='CLIENTE', ylabel='count'>

# %%
sns.countplot(x='PRODUCTO', data= data1)
# Out:
# <AxesSubplot:xlabel='PRODUCTO', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize':(10,8)})
sns.set_style('white')
sns.catplot(y='CLIENTE', x='Venta FEB21', data= data1)

# %%
sns.barplot(x='CLIENTE', y='Venta FEB21', data= data1)
# Out:
# <AxesSubplot:xlabel='CLIENTE', ylabel='Venta FEB21'>

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.set_style('white')
sns.barplot(x='TIENDA', y='Venta FEB21', data= data1)
# Out:
# <AxesSubplot:xlabel='TIENDA', ylabel='Venta FEB21'>

# %%
sns.boxplot(x='CLIENTE', y='Venta FEB21', data= data1, hue='TIENDA')
# Out:
# <AxesSubplot:xlabel='CLIENTE', ylabel='Venta FEB21'>

# %%
sns.boxplot(y='PRODUCTO', x='Venta FEB21', data= data1)
# Out:
# <AxesSubplot:xlabel='Venta FEB21', ylabel='PRODUCTO'>

# %%
sns.boxplot(y='PRODUCTO', x='Ctd Vendida FEB21', data= data1)
# Out:
# <AxesSubplot:xlabel='Ctd Vendida FEB21', ylabel='PRODUCTO'>

# %%
sns.relplot(x='Ctd Vendida FEB21', y='Venta FEB21', data=data1)

# %%
sns.relplot(x='Ctd Vendida FEB21', y='Venta FEB21', data=data1, hue='CLIENTE')

# %%
sns.relplot(x='Ctd Vendida FEB21', y='Venta FEB21', data=data1, hue='TIENDA')

# %%
sns.jointplot(x='Ctd Vendida FEB21', y='Venta FEB21', data=data1)

# %%
CyR=data1[data1['PRODUCTO']=='CERVEZAS Y REFRESCOS']
CyR
# Out:
#      COD TIENDA   TIENDA                   CLIENTE  Main Group Articulo  \
# 52            1    Chaco     Comercio de Alimentos                  2.0
# 103           1    Chaco   Procesador de Alimentos                  2.0
# 154           1    Chaco  Comercio de No Alimentos                  2.0
# 205           1    Chaco  Prestadores de Servicios                  2.0
# 256           1    Chaco      Consumidores Finales                  2.0
# ...         ...      ...                       ...                  ...
# 6529         23  Columna   Procesador de Alimentos                  2.0
# 6580         23  Columna  Comercio de No Alimentos                  2.0
# 6631         23  Columna  Prestadores de Servicios                  2.0
# 6682         23  Columna      Consumidores Finales                  2.0
# 6733         23  Columna  Clientes de Gran Volumen                  2.0
#
#                   PRODUCTO  Venta FEB21  Venta ENE21  Venta DIC20  \
# ...

# %%
sns.displot(CyR, x='Venta FEB21', hue='TIENDA')

# %%
sns.distplot(CyR['Venta FEB21'])
# Out:
# C:\Users\vitto\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Venta FEB21', ylabel='Density'>

# %%
sns.boxplot(y='TIENDA', x='Venta FEB21', data=CyR)
# Out:
# <AxesSubplot:xlabel='Venta FEB21', ylabel='TIENDA'>

# %%
sns.boxplot(y='CLIENTE', x='Ctd Vendida FEB21', data=CyR)
# Out:
# <AxesSubplot:xlabel='Ctd Vendida FEB21', ylabel='CLIENTE'>
